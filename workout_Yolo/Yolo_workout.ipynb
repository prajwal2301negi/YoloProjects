# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 22.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Push-Up**

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/push3.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

video_writer = cv2.VideoWriter("workouts_push_up.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

gym = solutions.AIGym(
    line_width=2,
    show=True,
    kpts=[6, 8, 10],
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = gym.monitor(im0)
    video_writer.write(im0)

cv2.destroyAllWindows()
video_writer.release()
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'line_width': 2, 'show': True, 'model': 'yolo11n-pose.pt'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 640x384 1 person, 13.0ms
# Speed: 2.7ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 14.1ms
# Speed: 3.1ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# ...

# %% [markdown]
# **Pull-Up**

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/pull2.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

video_writer = cv2.VideoWriter("workouts_pull_up.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

gym = solutions.AIGym(
    line_width=2,
    show=True,
    kpts=[6, 8, 10],
)
/
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = gym.monitor(im0)
    video_writer.write(im0)

cv2.destroyAllWindows()
video_writer.release()
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'line_width': 2, 'show': True, 'model': 'yolo11n-pose.pt'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 384x640 1 person, 14.8ms
# Speed: 2.6ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 18.8ms
# Speed: 3.4ms preprocess, 18.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.4ms
# Speed: 3.1ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
